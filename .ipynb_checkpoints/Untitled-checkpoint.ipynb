# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
results = [[10, 0],
 [10, 0],
 [10, 0],
 [10, 0],
 [10, 1],
 [40, 1],
 [40, 1],
 [40, 1],
 [40, 2],
 [40, 1],
 [70, 2],
 [70, 2],
 [70, 1],
 [70, 1],
 [70, 2],
 [100, 1],
 [100, 1],
 [100, 2],
 [100, 2],
 [100, 2],
 [130, 2],
 [130, 2],
 [130, 2],
 [130, 3],
 [130, 2],
 [160, 3],
 [160, 2],
 [160, 2],
 [160, 3],
 [160, 3],
 [190, 2],
 [190, 3],
 [190, 2],
 [190, 2],
 [190, 2],
 [220, 2],
 [220, 4],
 [220, 4],
 [220, 4],
 [220, 2],
 [250, 2],
 [250, 3],
 [250, 3],
 [250, 2],
 [250, 4],
 [280, 5],
 [280, 4],
 [280, 3],
 [280, 3],
 [280, 4],
 [310, 3],
 [310, 3],
 [310, 2],
 [310, 3],
 [310, 2],
 [340, 3],
 [340, 5],
 [340, 4],
 [340, 3],
 [340, 4],
 [370, 5],
 [370, 4],
 [370, 6],
 [370, 3],
 [370, 4],
 [400, 5],
 [400, 4],
 [400, 3],
 [400, 3],
 [400, 2],
 [430, 7],
 [430, 6],
 [430, 4],
 [430, 8],
 [430, 4],
 [460, 4],
 [460, 4],
 [460, 5],
 [460, 5],
 [460, 5],
 [490, 4],
 [490, 5],
 [490, 3],
 [490, 4],
 [490, 5],
 [520, 5],
 [520, 7],
 [520, 6],
 [520, 5],
 [520, 5],
 [550, 5],
 [550, 4],
 [550, 7],
 [550, 5],
 [550, 8],
 [580, 4],
 [580, 5],
 [580, 5],
 [580, 6],
 [580, 6],
 [610, 6],
 [610, 7],
 [610, 5],
 [610, 7],
 [610, 5],
 [640, 9],
 [640, 5],
 [640, 8],
 [640, 6],
 [640, 6],
 [670, 8],
 [670, 9],
 [670, 8],
 [670, 6],
 [670, 9],
 [700, 8],
 [700, 9],
 [700, 8],
 [700, 9],
 [700, 6],
 [730, 8],
 [730, 10],
 [730, 10],
 [730, 9],
 [730, 9],
 [760, 10],
 [760, 10],
 [760, 9],
 [760, 5],
 [760, 12],
 [790, 8],
 [790, 8],
 [790, 6],
 [790, 9],
 [790, 10],
 [820, 9],
 [820, -1],
 [820, 12],
 [820, 8],
 [820, 8],
 [850, 9],
 [850, 10],
 [850, 12],
 [850, 9],
 [850, 11],
 [880, 10],
 [880, 10],
 [880, 15],
 [880, 9],
 [880, 12],
 [910, 9],
 [910, 13],
 [910, 11],
 [910, 17],
 [910, 8],
 [940, 9],
 [940, 19],
 [940, -1],
 [940, 9],
 [940, 9],
 [970, 7],
 [970, -1],
 [970, 11],
 [970, 11],
 [970, 11],
 [1000, 8],
 [1000, -1],
 [1000, 8],
 [1000, 9],
 [1000, 12],
 [1300, -1],
 [1300, 11],
 [1300, -1],
 [1300, -1],
 [1300, -1],
 [1600, -1],
 [1600, -1],
 [1600, -1],
 [1600, -1],
 [1600, -1],
 [1100, 13],
 [1100, -1],
 [1100, -1],
 [1100, -1],
 [1100, -1]]

# %%
# results_new = [
# [1000, 8],[1000, -1],[1000, 8],[1000, 9],[1000, 12],
# [1300, -1],[1300, 11],[1300, -1],[1300, -1],[1300, -1],
#   [1600, -1],[1600, -1],[1600, -1],[1600, -1],[1600, -1],  
# ]

# %%
results_d = []
results_nd = []
for x, y in (results):
    if y == -1:
        results_d.append([x,y])
    else:
        results_nd.append([x,y])

# %%
fig, ax = plt.subplots(figsize = (10,8))

ax.scatter(*zip(*results_d), color = 'red', label = 'unsuccesfull training', alpha = 0.3)
ax.scatter(*zip(*results_nd), color = 'blue', label = 'successful training', alpha = 0.3)

ax.legend(loc='upper left')
ax.set_title('Epochs until convergence with different number of elements')
ax.set_xlabel('columns')
ax.set_ylabel('epochs to 80 percent train and val ac')
ax.grid(axis="x", which = 'both')
plt.show()
