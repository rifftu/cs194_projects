# %%
from glob import glob

# %%
import numpy as np

# %%
import skimage.io as skio

# %%
dog1 = skio.imread("CU_dogs/training_133/005.alaskan_malamute/alaskan_malamute_001.jpg")
dog2 = skio.imread("CU_dogs/training_133/005.alaskan_malamute/alaskan_malamute_002.jpg")
dog3 = skio.imread("CU_dogs/training_133/005.alaskan_malamute/alaskan_malamute_006.jpg")

# %%
import pandas as pd

# %%
pt1 = pd.read_csv("CU_dogs/training_parts_15pts/005.alaskan_malamute/alaskan_malamute_001.txt", sep = ' ', header = None)
pt2 = pd.read_csv("CU_dogs/training_parts_15pts/005.alaskan_malamute/alaskan_malamute_002.txt", sep = ' ',header = None)
pt3 = pd.read_csv("CU_dogs/training_parts_15pts/005.alaskan_malamute/alaskan_malamute_006.txt", sep = ' ',header = None)

# %%
pt1 = np.array(pt1)
pt2 = np.array(pt2)
pt3 = np.array(pt3)

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline
plt.figure(figsize = (16,12))
plt.imshow(dog1)
plt.scatter(*zip(*pt1))

# %%
# %matplotlib inline
plt.figure(figsize = (16,12))
plt.imshow(dog2)
plt.scatter(*zip(*pt2))

# %%
# %matplotlib inline
plt.figure(figsize = (16,12))
plt.imshow(dog3)
plt.scatter(*zip(*pt3))
