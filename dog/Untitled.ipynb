# %%
from glob import glob

# %%
import numpy as np

# %%
import skimage.io as skio

# %%
basenji = skio.imread("CU_dogs/training_133/014.basenji/basenji_004.jpg")

# %%
basenji_points = [79.122519, 113.881363,
118.064000, 110.423202,
102.692839, 152.081536,
50.571038, 56.172131,
76.811475, 85.625683,
94.293333, 82.650147,
110.549180, 80.806011,
127.840000, 44.570215,
73.975410, 113.266178,
85.005608, 116.551769,
112.933132, 112.796808,
121.381795, 107.633736,
98.687947, 153.037627,
107.754613 ,152.130960,
103.780414, 161.376618]

# %%
basenji_points = np.array(basenji_points).reshape((15, 2))

# %%
basenji_points
# Out:
# array([[ 79.122519, 113.881363],
#        [118.064   , 110.423202],
#        [102.692839, 152.081536],
#        [ 50.571038,  56.172131],
#        [ 76.811475,  85.625683],
#        [ 94.293333,  82.650147],
#        [110.54918 ,  80.806011],
#        [127.84    ,  44.570215],
#        [ 73.97541 , 113.266178],
#        [ 85.005608, 116.551769],
#        [112.933132, 112.796808],
#        [121.381795, 107.633736],
#        [ 98.687947, 153.037627],
#        [107.754613, 152.13096 ],
#        [103.780414, 161.376618]])

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline
plt.figure(figsize = (8,6))
plt.imshow(basenji)
plt.scatter(*zip(*basenji_points))
